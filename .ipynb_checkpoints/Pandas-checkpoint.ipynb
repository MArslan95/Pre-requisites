# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas_datareader as pdr

# %%
amzn= pdr.get_data_yahoo('AMZN','20121101')
goog=pdr.get_data_yahoo('GOOG','2012-11-01')

# %%
amzn.head()
# Out:
#                High      Low     Open    Close      Volume  Adj Close
# Date
# 2012-10-31  11.9350  11.5250  11.8160  11.6445  95952000.0    11.6445
# 2012-11-01  11.7275  11.5670  11.7115  11.6070  78102000.0    11.6070
# 2012-11-02  11.8700  11.6055  11.7005  11.6210  67494000.0    11.6210
# 2012-11-05  11.7415  11.5055  11.6020  11.7165  36922000.0    11.7165
# 2012-11-06  11.8875  11.7225  11.7705  11.8780  53226000.0    11.8780

# %%
amzn.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-07-12  113.230003  108.339996  112.160004  109.220001  54280300.0
# 2022-07-13  111.779999  106.010002  107.029999  110.400002  61353800.0
# 2022-07-14  111.180000  107.580002  110.239998  110.629997  51163100.0
# 2022-07-15  115.589996  111.589996  112.500000  113.550003  83891100.0
# 2022-07-18  116.570000  114.550003  115.000000  115.635002  12055404.0
#
#              Adj Close
# Date
# 2022-07-12  109.220001
# 2022-07-13  110.400002
# 2022-07-14  110.629997
# 2022-07-15  113.550003
# 2022-07-18  115.635002

# %%
print(amzn.info(),goog.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2444 entries, 2012-10-31 to 2022-07-18
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       2444 non-null   float64
#  1   Low        2444 non-null   float64
#  2   Open       2444 non-null   float64
#  3   Close      2444 non-null   float64
#  4   Volume     2444 non-null   float64
#  5   Adj Close  2444 non-null   float64
# dtypes: float64(6)
# memory usage: 133.7 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2092 entries, 2014-03-27 to 2022-07-18
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       2092 non-null   float64
#  1   Low        2092 non-null   float64
#  2   Open       2092 non-null   float64
#  3   Close      2092 non-null   float64
#  4   Volume     2092 non-null   float64
#  5   Adj Close  2092 non-null   float64
# dtypes: float64(6)
# memory usage: 114.4 KB
# None None

# %%
amzn['Open']
# Out:
# Date
# 2012-10-31     11.816000
# 2012-11-01     11.711500
# 2012-11-02     11.700500
# 2012-11-05     11.602000
# 2012-11-06     11.770500
#                  ...
# 2022-07-12    112.160004
# 2022-07-13    107.029999
# 2022-07-14    110.239998
# 2022-07-15    112.500000
# 2022-07-18    115.000000
# Name: Open, Length: 2444, dtype: float64

# %%
amzn.loc[:,'Open']
# Out:
# Date
# 2012-10-31     11.816000
# 2012-11-01     11.711500
# 2012-11-02     11.700500
# 2012-11-05     11.602000
# 2012-11-06     11.770500
#                  ...
# 2022-07-12    112.160004
# 2022-07-13    107.029999
# 2022-07-14    110.239998
# 2022-07-15    112.500000
# 2022-07-18    115.000000
# Name: Open, Length: 2444, dtype: float64

# %%
#Iloc uses on the basis of numbers 0,1
amzn.iloc[0,1]
# Out:
# 11.524999618530273

# %%
# Slice using index
amzn[amzn.index > '2017-11-10']
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-11-13   56.994999   56.117001   56.150002   56.458500  58368000.0
# 2017-11-14   56.900002   56.194500   56.505501   56.841999  62768000.0
# 2017-11-15   56.587502   56.081501   56.350498   56.334499  78574000.0
# 2017-11-16   56.908001   56.502499   56.507999   56.864498  44266000.0
# 2017-11-17   56.939999   56.290501   56.914001   56.493999  48268000.0
# ...                ...         ...         ...         ...         ...
# 2022-07-12  113.230003  108.339996  112.160004  109.220001  54280300.0
# 2022-07-13  111.779999  106.010002  107.029999  110.400002  61353800.0
# 2022-07-14  111.180000  107.580002  110.239998  110.629997  51163100.0
# 2022-07-15  115.589996  111.589996  112.500000  113.550003  83891100.0
# 2022-07-18  116.570000  114.550003  115.000000  115.635002  12055404.0
#
#              Adj Close
# Date
# 2017-11-13   56.458500
# 2017-11-14   56.841999
# 2017-11-15   56.334499
# 2017-11-16   56.864498
# 2017-11-17   56.493999
# ...                ...
# 2022-07-12  109.220001
# 2022-07-13  110.400002
# 2022-07-14  110.629997
# 2022-07-15  113.550003
# 2022-07-18  115.635002
#
# [1176 rows x 6 columns]

# %%
# Filtering the data
print('Mean: %.3f std: %.3f'% (amzn['Volume'].mean(), amzn['Volume'].std()) )
# Out:
# Mean: 80448684.740 std: 42512360.244

# %%
high= amzn['Volume'].mean() + 2* amzn['Volume'].std()

# %%
# len[amzn[amzn.Volume > high]]

# %%
amzn['pct_chng']=amzn.Close.pct_change()

# %%
amzn.head()
# Out:
#                High      Low     Open    Close      Volume  Adj Close  \
# Date
# 2012-10-31  11.9350  11.5250  11.8160  11.6445  95952000.0    11.6445
# 2012-11-01  11.7275  11.5670  11.7115  11.6070  78102000.0    11.6070
# 2012-11-02  11.8700  11.6055  11.7005  11.6210  67494000.0    11.6210
# 2012-11-05  11.7415  11.5055  11.6020  11.7165  36922000.0    11.7165
# 2012-11-06  11.8875  11.7225  11.7705  11.8780  53226000.0    11.8780
#
#             pct_chng
# Date
# 2012-10-31       NaN
# 2012-11-01 -0.003220
# 2012-11-02  0.001206
# 2012-11-05  0.008218
# 2012-11-06  0.013784

# %%
goog_l1=goog.loc['2017-11']
amzn_l1=amzn.loc['2017-11']

# %%
goog_l1.append(amzn_l1).head()
# Out:
# C:\Users\Arsla\AppData\Local\Temp\ipykernel_7556\256416783.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   goog_l1.append(amzn_l1).head()
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2017-11-01  51.483501  50.847500  50.860500  51.275002  27468880.0  51.275002
# 2017-11-02  51.404499  50.650501  51.088001  51.278999  20979400.0  51.278999
# 2017-11-03  51.632500  51.015499  51.105499  51.624001  21527000.0  51.624001
# 2017-11-06  51.743500  51.250000  51.449501  51.294998  22503700.0  51.294998
# 2017-11-07  51.698502  51.256500  51.363499  51.666500  22246620.0  51.666500
#
#             pct_chng
# Date
# 2017-11-01       NaN
# 2017-11-02       NaN
# 2017-11-03       NaN
# 2017-11-06       NaN
# 2017-11-07       NaN

# %%
goog_l1.append(amzn_l1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 42 entries, 2017-11-01 to 2017-11-30
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       42 non-null     float64
#  1   Low        42 non-null     float64
#  2   Open       42 non-null     float64
#  3   Close      42 non-null     float64
#  4   Volume     42 non-null     float64
#  5   Adj Close  42 non-null     float64
#  6   pct_chng   21 non-null     float64
# dtypes: float64(7)
# memory usage: 2.6 KB
# C:\Users\Arsla\AppData\Local\Temp\ipykernel_7556\3163685565.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   goog_l1.append(amzn_l1).info()

# %% [markdown]
# ### Merging Column from different Data Frames

# %%
close=pd.DataFrame({'AMZN': amzn.Close, 'GOOG': goog.Close})
close.head()
# Out:
#                AMZN  GOOG
# Date
# 2012-10-31  11.6445   NaN
# 2012-11-01  11.6070   NaN
# 2012-11-02  11.6210   NaN
# 2012-11-05  11.7165   NaN
# 2012-11-06  11.8780   NaN

# %% [markdown]
# ### Grouping and Sorting

# %%
amzn.groupby(['Open']).sum()
# Out:
#                   High         Low       Close       Volume   Adj Close  \
# Open
# 11.065500    11.312500   10.932000   11.261500   87056000.0   11.261500
# 11.115000    11.258000   10.909000   11.030000   68094000.0   11.030000
# 11.256000    11.395000   11.235500   11.330000   52596000.0   11.330000
# 11.313000    11.548500   11.230000   11.315500   61850000.0   11.315500
# 11.325000    11.370500   11.125500   11.147500   60682000.0   11.147500
# ...                ...         ...         ...          ...         ...
# 185.442505  185.882996  183.041504  184.084000   65932000.0  184.084000
# 185.634506  188.107498  183.785995  183.828506   98734000.0  183.828506
# 185.869003  186.710007  183.945496  184.828995  106562000.0  184.828995
# 186.126007  187.399994  184.669998  185.966995   74964000.0  185.966995
# 187.199997  187.864502  184.839493  185.927505   51432000.0  185.927505
#
#             pct_chng
# Open
# 11.065500   0.020988
# 11.115000  -0.010541
# 11.256000   0.000574
# 11.313000  -0.004574
# 11.325000  -0.016108
# ...              ...
# 185.442505  0.001175
# 185.634506 -0.005273
# 185.869003  0.005670
# 186.126007 -0.003235
# 187.199997 -0.000212
#
# [2364 rows x 6 columns]

# %% [markdown]
# ### Grouping by resampleing the data

# %%
goog['Volume'][goog.index>'2017'].resample('M').mean()
# Out:
# Date
# 2017-01-31    3.333282e+07
# 2017-02-28    2.704160e+07
# 2017-03-31    2.942638e+07
# 2017-04-30    2.654581e+07
# 2017-05-31    2.926389e+07
#                   ...
# 2022-03-31    2.771593e+07
# 2022-04-30    2.824728e+07
# 2022-05-31    3.416595e+07
# 2022-06-30    2.986503e+07
# 2022-07-31    2.925835e+07
# Freq: M, Name: Volume, Length: 67, dtype: float64

# %%
# Ploting using matplot
goog['Volume'][goog.index >'2017'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
amzn_change=np.log(amzn.Close/amzn.Close.shift(1))
goog_change=np.log(goog.Close/goog.Close.shift(1))

# %%
amzn_change.cumsum().plot()
goog_change.cumsum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
new=pd.DataFrame({'AMZN': amzn_change[1:],'GOOG': goog_change[1:]})
new.to_csv('Stocks.csv')

# %%
pd.read_csv('Stocks.csv').head()
# Out:
#          Date      AMZN  GOOG
# 0  2012-11-01 -0.003226   NaN
# 1  2012-11-02  0.001205   NaN
# 2  2012-11-05  0.008184   NaN
# 3  2012-11-06  0.013690   NaN
# 4  2012-11-07 -0.023424   NaN

# %%
# Change index and remove Columns
new_stocks=pd.read_csv('Stocks.csv')
new_stocks.index=new_stocks.Date
new_stocks.head()
# Out:
#                   Date      AMZN  GOOG
# Date
# 2012-11-01  2012-11-01 -0.003226   NaN
# 2012-11-02  2012-11-02  0.001205   NaN
# 2012-11-05  2012-11-05  0.008184   NaN
# 2012-11-06  2012-11-06  0.013690   NaN
# 2012-11-07  2012-11-07 -0.023424   NaN

# %%
new_stocks.drop(['Date'], axis=1, inplace=True)
new_stocks.head()
# Out:
#                 AMZN  GOOG
# Date
# 2012-11-01 -0.003226   NaN
# 2012-11-02  0.001205   NaN
# 2012-11-05  0.008184   NaN
# 2012-11-06  0.013690   NaN
# 2012-11-07 -0.023424   NaN

# %%
new_stocks.rename(columns={'AMZN':'AMZN_CHNG'}, inplace=True)
new_stocks.head()
# Out:
#             AMZN_CHNG  GOOG
# Date
# 2012-11-01  -0.003226   NaN
# 2012-11-02   0.001205   NaN
# 2012-11-05   0.008184   NaN
# 2012-11-06   0.013690   NaN
# 2012-11-07  -0.023424   NaN
